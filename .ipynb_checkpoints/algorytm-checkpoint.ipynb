# %%
def initbool(dlugosc):
    return [False for i in range(dlugosc)]

def create_matrix(words):
    L = len(words[0])
    matrix = []
    for i in range(len(words)):
        row = []
        for j in range(len(words)):
            suc = 0
            if i==j:
                row.append(1000)
                continue
            for x in range(1,L):
                if words[i][x:] == words[j][:L-x]:
                    row.append(x)
                    suc = 1
                    break
            if suc==0: 
                row.append(L)
        matrix.append(row)


    return(matrix)


def sekwencjonuj(L, S, N, Graf): 
#L - długość słowa, S - zbiór słów,
#N - długość oryginalnej sekwencji, Graf - utworzony graf z wagami (x->y) 
#np graf[x][y] oznacza wagę połączenia wyrazów S[x](np ATT) z S[y](np TTA) - czyli w tym wypadku 1
#zbiór S uporządkowany tak samo jak graf!

    def DFS(DlugoscSekwencji, Sekwencja, wyrazy, indeks, najlepsze):
        
        odwiedzone[indeks] = True
        print(odwiedzone)
        print("wyrazów: ", wyrazy, " sekwencja: ", Sekwencja, " Długość: ", DlugoscSekwencji)
        for i in range(len(S)):
            if odwiedzone[i] == False:
                if DlugoscSekwencji+Graf[i][indeks] < N:
                    Sekwencja.append(S[indeks])
                    DFS(DlugoscSekwencji+Graf[i][indeks], Sekwencja, wyrazy+1, i, najlepsze)
                elif DlugoscSekwencji+Graf[i][indeks] == N:
                    if wyrazy+1 > najlepsze[2]: #and DlugosSekwnecji+Graf[i][indeks] =< najelpsze[0]: 
                        najlepsze[2] = wyrazy + 1 #wyrazy
                        najlepsze[1] = Sekwencja.append(S[i])#sekwencja
                        najlepsze[0] = DlugoscSekwencji+graf[i][indeks]#długość sekwencji
                        odwiedzone[i]=True
                else: # DlugoscSekwnecji+Graf[i][indeks] > N
                    if wyrazy > najlepsze[2]:  #and DlugosSekwnecji =< najelpsze[0]: 
                        najlepsze[2] = wyrazy #wyrazy
                        najlepsze[1] = Sekwencja #sekwencja
                        najlepsze[0] = DlugoscSekwencji #długość sekwencji
        return najlepsze
                    
    DlugoscSekwencji = L
    wyrazy = 1
    Sekwencja = [S[0]]

    rozwiazanie=[DlugoscSekwencji, Sekwencja, wyrazy]
    #długość sekwencji w najlepszym (logalnie) rozwiązaniu
    #sekwencja w najlepszym rozwiązaniu
    #ilość wyrazów w najlepszym rozwiązaniu

        
    for i in range(len(S)):
        odwiedzone=initbool(len(S))
        print(S[i])
        noweRozwiazanie=DFS(L,  [S[i]], 0, i, rozwiazanie)
        
        if noweRozwiazanie[2] > rozwiazanie[2]:
            rozwiazanie = noweRozwiazanie 
            #preferowane jestrozwiązanie o większej lizbie wyrazów...
        elif noweRozwiazanie[2] == rozwiazanie[2] and noweRozwiazanie[0] < rozwiazanie[0]:
            #...a spośród tych mających tyle samo wyrazów to, które ma mniejszą długość
            rozwiazanie = noweRozwiazanie 
    

    return rozwiazanie
    
#dane testowe
    
S=["AAT", "ACG", "CCG", "CGT", "GAC", "TTG"]

graf= [[10000, 3, 3, 3, 3, 2],
       [3, 10000, 3, 1, 2, 3],
       [3, 3, 10000, 1, 2, 3],
       [3, 3, 3, 10000, 3, 2], 
       [3, 1, 2, 2, 10000, 3], 
       [3, 3, 3, 3, 2, 10000]]

L = 3
N = 8
seq = sekwencjonuj(L, S, N, create_matrix(S))
seq

#DFS(DlugoscSekwencji, Sekwescja, wyrazy, indeks, najlepsze)
#DFS(DlugoscSekwencji+Graf[i][indeks], Sekwencja.append(S[indeks]), wyrazy+1, i, najlepsze)
#DFS(L,  [S[i]], wyrazy, i, rozwiazanie)
# Out:
# AAT
# [True, False, False, False, False, False]
# wyrazów:  0  sekwencja:  ['AAT']  Długość:  3
# [True, True, False, False, False, False]
# wyrazów:  1  sekwencja:  ['AAT', 'AAT']  Długość:  6
# [True, True, False, False, True, False]
# wyrazów:  2  sekwencja:  ['AAT', 'AAT', 'ACG']  Długość:  7
# [True, True, True, False, True, False]
# wyrazów:  1  sekwencja:  ['AAT', 'AAT', 'ACG', 'AAT']  Długość:  6
# [True, True, True, True, True, False]
# wyrazów:  1  sekwencja:  ['AAT', 'AAT', 'ACG', 'AAT', 'AAT']  Długość:  6
# [True, True, True, True, True, True]
# wyrazów:  1  sekwencja:  ['AAT', 'AAT', 'ACG', 'AAT', 'AAT', 'AAT']  Długość:  6
# ACG
# [False, True, False, False, False, False]
# wyrazów:  0  sekwencja:  ['ACG']  Długość:  3
# [True, True, False, False, False, False]
# wyrazów:  1  sekwencja:  ['ACG', 'ACG']  Długość:  6
# [True, True, True, False, False, False]
# wyrazów:  1  sekwencja:  ['ACG', 'ACG', 'ACG']  Długość:  6
# [True, True, True, True, False, False]
# wyrazów:  1  sekwencja:  ['ACG', 'ACG', 'ACG', 'ACG']  Długość:  6
# [True, True, True, True, True, False]
# wyrazów:  1  sekwencja:  ['ACG', 'ACG', 'ACG', 'ACG', 'ACG']  Długość:  4
# [True, True, True, True, True, True]
# wyrazów:  2  sekwencja:  ['ACG', 'ACG', 'ACG', 'ACG', 'ACG', 'GAC']  Długość:  6
# CCG
# [False, False, True, False, False, False]
# wyrazów:  0  sekwencja:  ['CCG']  Długość:  3
# [True, False, True, False, False, False]
# wyrazów:  1  sekwencja:  ['CCG', 'CCG']  Długość:  6
# [True, True, True, False, False, False]
# wyrazów:  1  sekwencja:  ['CCG', 'CCG', 'CCG']  Długość:  6
# [True, True, True, False, True, False]
# wyrazów:  2  sekwencja:  ['CCG', 'CCG', 'CCG', 'ACG']  Długość:  7
# [True, True, True, True, True, False]
# wyrazów:  1  sekwencja:  ['CCG', 'CCG', 'CCG', 'ACG', 'CCG']  Długość:  6
# [True, True, True, True, True, True]
# wyrazów:  1  sekwencja:  ['CCG', 'CCG', 'CCG', 'ACG', 'CCG', 'CCG']  Długość:  6
# CGT
# [False, False, False, True, False, False]
# wyrazów:  0  sekwencja:  ['CGT']  Długość:  3
# [True, False, False, True, False, False]
# wyrazów:  1  sekwencja:  ['CGT', 'CGT']  Długość:  6
# [True, True, False, True, False, False]
# wyrazów:  1  sekwencja:  ['CGT', 'CGT', 'CGT']  Długość:  4
# [True, True, True, True, False, False]
# wyrazów:  2  sekwencja:  ['CGT', 'CGT', 'CGT', 'ACG']  Długość:  7
# [True, True, True, True, True, False]
# wyrazów:  2  sekwencja:  ['CGT', 'CGT', 'CGT', 'ACG', 'ACG']  Długość:  5
# [True, True, True, True, True, True]
# wyrazów:  3  sekwencja:  ['CGT', 'CGT', 'CGT', 'ACG', 'ACG', 'GAC']  Długość:  7
# GAC
# [False, False, False, False, True, False]
# wyrazów:  0  sekwencja:  ['GAC']  Długość:  3
# [True, False, False, False, True, False]
# wyrazów:  1  sekwencja:  ['GAC', 'GAC']  Długość:  6
# [True, True, False, False, True, False]
# wyrazów:  1  sekwencja:  ['GAC', 'GAC', 'GAC']  Długość:  5
# [True, True, True, False, True, False]
# wyrazów:  1  sekwencja:  ['GAC', 'GAC', 'GAC', 'GAC']  Długość:  5
# [True, True, True, True, True, False]
# wyrazów:  1  sekwencja:  ['GAC', 'GAC', 'GAC', 'GAC', 'GAC']  Długość:  6
# [True, True, True, True, True, True]
# wyrazów:  1  sekwencja:  ['GAC', 'GAC', 'GAC', 'GAC', 'GAC', 'GAC']  Długość:  5
# TTG
# [False, False, False, False, False, True]
# wyrazów:  0  sekwencja:  ['TTG']  Długość:  3
# [True, False, False, False, False, True]
# wyrazów:  1  sekwencja:  ['TTG', 'TTG']  Długość:  5
# [True, True, False, False, False, True]
# wyrazów:  1  sekwencja:  ['TTG', 'TTG', 'TTG']  Długość:  6
# [True, True, False, False, True, True]
# wyrazów:  2  sekwencja:  ['TTG', 'TTG', 'TTG', 'ACG']  Długość:  7
# [True, True, True, False, True, True]
# wyrazów:  1  sekwencja:  ['TTG', 'TTG', 'TTG', 'ACG', 'TTG']  Długość:  6
# [True, True, True, True, True, True]
# wyrazów:  1  sekwencja:  ['TTG', 'TTG', 'TTG', 'ACG', 'TTG', 'TTG']  Długość:  5
# [7, ['AAT', 'AAT', 'ACG', 'AAT', 'AAT', 'AAT'], 2]
