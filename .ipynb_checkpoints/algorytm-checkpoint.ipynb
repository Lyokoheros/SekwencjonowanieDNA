# %%
def initbool(dlugosc):
    return [False for i in range(dlugosc)]

def create_matrix(words):
    L = len(words[0])
    matrix = []
    for i in range(len(words)):
        row = []
        for j in range(len(words)):
            suc = 0
            if i==j:
                row.append(1000)
                continue
            for x in range(1,L):
                if words[i][x:] == words[j][:L-x]:
                    row.append(x)
                    suc = 1
                    break
            if suc==0: 
                row.append(L)
        matrix.append(row)


    return(matrix)

def read_data(file_name,L):
    words = []
    file = open("instances/"+file_name+".txt")
    data = file.readline(L)
    while data!="":
        words.append(data)
        file.readline()
        data = file.readline(L)

        
    file.close()
    return words

def sekwencjonuj(L, S, N, Graf): 
#L - długość słowa, S - zbiór słów,
#N - długość oryginalnej sekwencji, Graf - utworzony graf z wagami (x->y) 
#np graf[x][y] oznacza wagę połączenia wyrazów S[x](np ATT) z S[y](np TTA) - czyli w tym wypadku 1
#zbiór S uporządkowany tak samo jak graf!

    def DFS(DlugoscSekwencji, Sekwencja, wyrazy, indeks, najlepsze):     
        odwiedzone[indeks] = True
        #print(odwiedzone)
        #print("wyrazów: ", wyrazy, " sekwencja: ", Sekwencja, " Długość: ", DlugoscSekwencji)
        ni=-1
        minW=1000
        #szukamy najlepszego dopasowania (jeszcze nie odwiedzonego kandydata do odwiedzenia o najniższym koszcie połączenia)
        for i in range(len(S)):
            if odwiedzone[i] == False and minW > Graf[indeks][i]:
                minW=Graf[indeks][i]
                ni=i 
                
        if ni==-1:
            return najlepsze
            
        #i patrzymy czy osiągneliśmy warunek brzegowy (czy jest sens szukać dalej)
        if DlugoscSekwencji+Graf[indeks][ni] < N:
            Sekwencja.append(S[ni])
            DFS(DlugoscSekwencji+Graf[indeks][ni], Sekwencja, wyrazy+1, ni, najlepsze)
        elif DlugoscSekwencji+Graf[indeks][ni] == N:
            if wyrazy+1 > najlepsze[2]: # and DlugoscSekwencji+Graf[indeks][ni] >= najlepsze[0]: 
                najlepsze[2] = wyrazy + 1 #wyrazy
                Sekwencja.append(S[ni])
                najlepsze[1] = Sekwencja#sekwencja
                najlepsze[0] = DlugoscSekwencji+Graf[indeks][ni]#długość sekwencji
                odwiedzone[ni]=True
            return najlepsze
        else: # DlugoscSekwnecji+Graf[indeks][ni] > N
            if wyrazy > najlepsze[2]: #and DlugoscSekwencji >= najlepsze[0]: 

                najlepsze[2] = wyrazy #wyrazy
                najlepsze[1] = Sekwencja #sekwencja
                najlepsze[0] = DlugoscSekwencji #długość sekwencji
            return najlepsze
            
          
        
        
    DlugoscSekwencji = L#N
    wyrazy = 1
    Sekwencja = [S[0]]

    rozwiazanie=[DlugoscSekwencji, Sekwencja, wyrazy]
    #długość sekwencji w najlepszym (logalnie) rozwiązaniu
    #sekwencja w najlepszym rozwiązaniu
    #ilość wyrazów w najlepszym rozwiązaniu

        
    for i in range(len(S)):
        odwiedzone=initbool(len(S))
        #print(i+1, " DFS, z wierzchołka:", S[i])
        
        noweRozwiazanie=DFS(L,  [S[i]], 1, i, rozwiazanie)
        
    
        if noweRozwiazanie == None:
            
            continue
            #print("wyrazów: ", noweRozwiazanie[2], " sekwencja: ", noweRozwiazanie[1], " Długość: ", noweRozwiazanie[0])
        if noweRozwiazanie[2] > rozwiazanie[2]:
            rozwiazanie = noweRozwiazanie 
            #preferowane jestrozwiązanie o większej lizbie wyrazów...
        elif noweRozwiazanie[2] == rozwiazanie[2] and noweRozwiazanie[0] < rozwiazanie[0]:
            #...a spośród tych mających tyle samo wyrazów to, które ma mniejszą długość
            rozwiazanie = noweRozwiazanie 
    

    return rozwiazanie

# %%
#dane testowe - test prosty
    
S=["AAT", "ACG", "CCG", "CGT", "GAC", "TTG"]

graf= [[10000, 3, 3, 3, 3, 2],
       [3, 10000, 3, 1, 2, 3],
       [3, 3, 10000, 1, 2, 3],
       [3, 3, 3, 10000, 3, 2], 
       [3, 1, 2, 2, 10000, 3], 
       [3, 3, 3, 3, 2, 10000]]

L = 3
N = 8
seq = sekwencjonuj(L, S, N, create_matrix(S))
#seq

S = read_data("9.200-40",10)

graf = create_matrix(S)

L = 10
N = 209
seq = sekwencjonuj(L, S, N, create_matrix(S))
seq


#DFS(DlugoscSekwencji, Sekwescja, wyrazy, indeks, najlepsze)
#DFS(DlugoscSekwencji+Graf[i][indeks], Sekwencja.append(S[indeks]), wyrazy+1, i, najlepsze)
#DFS(L,  [S[i]], wyrazy, i, rozwiazanie)
# Out:
# 1  DFS, z wierzchołka: AAT
# None
# 2  DFS, z wierzchołka: ACG
# None
# 3  DFS, z wierzchołka: CCG
# None
# 4  DFS, z wierzchołka: CGT
# None
# 5  DFS, z wierzchołka: GAC
# None
# 6  DFS, z wierzchołka: TTG
# None
# 1  DFS, z wierzchołka: AAGGCCGGCT
# None
# 2  DFS, z wierzchołka: ACACCCGCCG
# None
# 3  DFS, z wierzchołka: ACCAGGGCGT
# None
# 4  DFS, z wierzchołka: ACCATGGATG
# None
# 5  DFS, z wierzchołka: ACCCGCCGCC
# None
# 6  DFS, z wierzchołka: ACGATGCCCC
# None
# 7  DFS, z wierzchołka: AGAAGGATTC
# None
# 8  DFS, z wierzchołka: AGCTCACCAT
# None
# 9  DFS, z wierzchołka: AGGCACCAGG
# None
# 10  DFS, z wierzchołka: AGGCCGGCTT
# None
# 11  DFS, z wierzchołka: AGGGCGTGAT
# None
# 12  DFS, z wierzchołka: ATATCGCCGC
# None
# 13  DFS, z wierzchołka: ATCCGCCGCC
# None
# 14  DFS, z wierzchołka: ATCGCCGCGC
# None
# 15  DFS, z wierzchołka: ATGATATCGC
# None
# 16  DFS, z wierzchołka: ATGATGATAT
# None
# 17  DFS, z wierzchołka: ATGCCCCCCG
# None
# 18  DFS, z wierzchołka: ATGGATGATG
# None
# 19  DFS, z wierzchołka: CAAGGCCGGC
# None
# 20  DFS, z wierzchołka: CACACCCGCC
# None
# 21  DFS, z wierzchołka: CACCCGCCGC
# None
# 22  DFS, z wierzchołka: CAGAAGGATT
# None
# 23  DFS, z wierzchołka: CAGCTCACCA
# None
# 24  DFS, z wierzchołka: CAGGCACCAG
# None
# 25  DFS, z wierzchołka: CAGGGCGTGA
# None
# 26  DFS, z wierzchołka: CATGGATGAT
# None
# 27  DFS, z wierzchołka: CATGGGTCAG
# None
# 28  DFS, z wierzchołka: CATGTGCAAG
# None
# 29  DFS, z wierzchołka: CCACACCCGC
# None
# 30  DFS, z wierzchołka: CCAGCTCACC
# None
# 31  DFS, z wierzchołka: CCAGGCACCA
# None
# 32  DFS, z wierzchołka: CCAGGGCGTG
# None
# 33  DFS, z wierzchołka: CCATCGTGGG
# None
# 34  DFS, z wierzchołka: CCATGGATGA
# None
# 35  DFS, z wierzchołka: CCCAGGCACC
# None
# 36  DFS, z wierzchołka: CCCCAGGCAC
# None
# 37  DFS, z wierzchołka: CCCCCCGGGC
# None
# 38  DFS, z wierzchołka: CCCCCGGGCC
# None
# 39  DFS, z wierzchołka: CCCCGGGCCG
# None
# 40  DFS, z wierzchołka: CCCCTCCATC
# None
# 41  DFS, z wierzchołka: CCCGCCGCCA
# None
# 42  DFS, z wierzchołka: CCCGGGCCGT
# None
# 43  DFS, z wierzchołka: CCCGTCCACA
# None
# 44  DFS, z wierzchołka: CCCTCCATCG
# None
# 45  DFS, z wierzchołka: CCGATCCGCC
# None
# 46  DFS, z wierzchołka: CCGCCGCCAG
# None
# 47  DFS, z wierzchołka: CCGCCGCCCG
# None
# 48  DFS, z wierzchołka: CCGCGCTCGT
# None
# 49  DFS, z wierzchołka: CCGGCTTCGC
# None
# 50  DFS, z wierzchołka: CCGGGCCGTC
# None
# 51  DFS, z wierzchołka: CCGTCCACAC
# None
# 52  DFS, z wierzchołka: CCGTCTTCCC
# None
# 53  DFS, z wierzchołka: CCTATGTGGG
# None
# 54  DFS, z wierzchołka: CCTCCATCGT
# None
# 55  DFS, z wierzchołka: CGACAACGGC
# None
# 56  DFS, z wierzchołka: CGACGATGCC
# None
# 57  DFS, z wierzchołka: CGATCCGCCG
# None
# 58  DFS, z wierzchołka: CGATGCCCCC
# None
# 59  DFS, z wierzchołka: CGCCAGCTCA
# None
# 60  DFS, z wierzchołka: CGCCCCAGGC
# None
# 61  DFS, z wierzchołka: CGCCCGTCCA
# None
# 62  DFS, z wierzchołka: CGCCGCCAGC
# None
# 63  DFS, z wierzchołka: CGCCGCGCTC
# None
# 64  DFS, z wierzchołka: CGCGCTCGTC
# None
# 65  DFS, z wierzchołka: CGCGGGCGAC
# None
# 66  DFS, z wierzchołka: CGCTCGTCGT
# None
# 67  DFS, z wierzchołka: CGGCATGTGC
# None
# 68  DFS, z wierzchołka: CGGCTCCGGC
# None
# 69  DFS, z wierzchołka: CGGCTTCGCG
# None
# 70  DFS, z wierzchołka: CGGGCCGTCT
# None
# 71  DFS, z wierzchołka: CGGGCGACGA
# None
# 72  DFS, z wierzchołka: CGTCGACAAC
# None
# 73  DFS, z wierzchołka: CGTCGTCGAC
# None
# 74  DFS, z wierzchołka: CGTCTTCCCC
# None
# 75  DFS, z wierzchołka: CGTGATGGTG
# None
# 76  DFS, z wierzchołka: CGTGGGGCGC
# None
# 77  DFS, z wierzchołka: CTATGTGGGC
# None
# 78  DFS, z wierzchołka: CTCCATCGTG
# None
# 79  DFS, z wierzchołka: CTCCGGCATG
# None
# 80  DFS, z wierzchołka: CTCGTCGTCG
# None
# 81  DFS, z wierzchołka: CTTCCCCTCC
# None
# 82  DFS, z wierzchołka: CTTCGCGGGC
# None
# 83  DFS, z wierzchołka: GAAGGATTCC
# None
# 84  DFS, z wierzchołka: GACAACGGCT
# None
# 85  DFS, z wierzchołka: GACGATGCCC
# None
# 86  DFS, z wierzchołka: GATATCGCCG
# None
# 87  DFS, z wierzchołka: GATCCGCCGC
# None
# 88  DFS, z wierzchołka: GATGATATCG
# None
# 89  DFS, z wierzchołka: GATGCCCCCC
# None
# 90  DFS, z wierzchołka: GATTCCTATG
# None
# 91  DFS, z wierzchołka: GCAAGGCCGG
# None
# 92  DFS, z wierzchołka: GCACCAGGGC
# None
# 93  DFS, z wierzchołka: GCATGGGTCA
# None
# 94  DFS, z wierzchołka: GCCAGCTCAC
# None
# 95  DFS, z wierzchołka: GCCCCAGGCA
# None
# 96  DFS, z wierzchołka: GCCCGTCCAC
# None
# 97  DFS, z wierzchołka: GCCGATCCGC
# None
# 98  DFS, z wierzchołka: GCCGCCAGCT
# None
# 99  DFS, z wierzchołka: GCCGGCTTCG
# None
# 100  DFS, z wierzchołka: GCGACGATGC
# None
# 101  DFS, z wierzchołka: GCGCCCCAGG
# None
# 102  DFS, z wierzchołka: GCGCTCGTCG
# None
# 103  DFS, z wierzchołka: GCGGGCGACG
# None
# 104  DFS, z wierzchołka: GCGTGATGGT
# None
# 105  DFS, z wierzchołka: GCTCACCATG
# None
# 106  DFS, z wierzchołka: GCTCCGGCAT
# None
# 107  DFS, z wierzchołka: GCTCGTCGTC
# None
# 108  DFS, z wierzchołka: GGATGATGAT
# None
# 109  DFS, z wierzchołka: GGATTCCTAT
# None
# 110  DFS, z wierzchołka: GGCATGGGTC
# None
# 111  DFS, z wierzchołka: GGCATGTGCA
# None
# 112  DFS, z wierzchołka: GGCCGGCTTC
# None
# 113  DFS, z wierzchołka: GGCCGTCTTC
# None
# 114  DFS, z wierzchołka: GGCGACGATG
# None
# 115  DFS, z wierzchołka: GGCGCCCCAG
# None
# 116  DFS, z wierzchołka: GGCGTGATGG
# None
# 117  DFS, z wierzchołka: GGCTCCGGCA
# None
# 118  DFS, z wierzchołka: GGCTTCGCGG
# None
# 119  DFS, z wierzchołka: GGGCATGGGT
# None
# 120  DFS, z wierzchołka: GGGCGACGAT
# None
# 121  DFS, z wierzchołka: GGGCGCCCCA
# None
# 122  DFS, z wierzchołka: GGGCGTGATG
# None
# 123  DFS, z wierzchołka: GGGGCGCCCC
# None
# 124  DFS, z wierzchołka: GGTCAGAAGG
# None
# 125  DFS, z wierzchołka: GGTGGGCATG
# None
# 126  DFS, z wierzchołka: GTCAGAAGGA
# None
# 127  DFS, z wierzchołka: GTCCACACCC
# None
# 128  DFS, z wierzchołka: GTCGACAACG
# None
# 129  DFS, z wierzchołka: GTCTTCCCCT
# None
# 130  DFS, z wierzchołka: GTGATGGTGG
# None
# 131  DFS, z wierzchołka: GTGCAAGGCC
# None
# 132  DFS, z wierzchołka: GTGGGCATGG
# None
# 133  DFS, z wierzchołka: GTGGGGCGCC
# None
# 134  DFS, z wierzchołka: TATGTGGGCG
# None
# 135  DFS, z wierzchołka: TCAGAAGGAT
# None
# 136  DFS, z wierzchołka: TCCACACCCG
# None
# 137  DFS, z wierzchołka: TCCATCGTGG
# None
# 138  DFS, z wierzchołka: TCCCCTCCAT
# None
# 139  DFS, z wierzchołka: TCCGCCGCCC
# None
# 140  DFS, z wierzchołka: TCCGGCATGT
# None
# 141  DFS, z wierzchołka: TCCTATGTGG
# None
# 142  DFS, z wierzchołka: TCGACAACGG
# None
# 143  DFS, z wierzchołka: TCGCCGCGCT
# None
# 144  DFS, z wierzchołka: TCGCGGGCGA
# None
# 145  DFS, z wierzchołka: TCGTCGTCGA
# None
# 146  DFS, z wierzchołka: TCGTGGGGCG
# None
# 147  DFS, z wierzchołka: TCTTCCCCTC
# None
# 148  DFS, z wierzchołka: TGATATCGCC
# None
# 149  DFS, z wierzchołka: TGATGATATC
# None
# 150  DFS, z wierzchołka: TGATGGTGGG
# None
# 151  DFS, z wierzchołka: TGCAAGGCCG
# None
# 152  DFS, z wierzchołka: TGCCCCCCGG
# None
# 153  DFS, z wierzchołka: TGCCGATCCG
# None
# 154  DFS, z wierzchołka: TGGGCATGGG
# None
# 155  DFS, z wierzchołka: TGGGGCGCCC
# None
# 156  DFS, z wierzchołka: TGGGTCAGAA
# None
# 157  DFS, z wierzchołka: TGTGCAAGGC
# None
# 158  DFS, z wierzchołka: TTCCTATGTG
# None
# 159  DFS, z wierzchołka: TTCGCGGGCG
# None
# 160  DFS, z wierzchołka: TTGCCGATCC
# None
# [206,
#  ['TGCCGATCCG',
#   'GCCGATCCGC',
#   'CCGATCCGCC',
#   'CGATCCGCCG',
#   'GATCCGCCGC',
#   'ATCCGCCGCC',
#   'TCCGCCGCCC',
#   'CCGCCGCCCG',
#   'CGCCCGTCCA',
#   'GCCCGTCCAC',
#   'CCCGTCCACA',
#   'CCGTCCACAC',
#   'GTCCACACCC',
#   'TCCACACCCG',
#   'CCACACCCGC',
#   'CACACCCGCC',
#   'ACACCCGCCG',
#   'CACCCGCCGC',
#   'ACCCGCCGCC',
#   'CCCGCCGCCA',
#   'CCGCCGCCAG',
#   'CGCCGCCAGC',
#   'GCCGCCAGCT',
#   'CGCCAGCTCA',
#   'GCCAGCTCAC',
#   'CCAGCTCACC',
#   'CAGCTCACCA',
#   'AGCTCACCAT',
#   'GCTCACCATG',
#   'ACCATGGATG',
#   'CCATGGATGA',
#   'CATGGATGAT',
#   'ATGGATGATG',
#   'GGATGATGAT',
#   'ATGATGATAT',
#   'TGATGATATC',
#   'GATGATATCG',
#   'ATGATATCGC',
#   'TGATATCGCC',
#   'GATATCGCCG',
#   'ATATCGCCGC',
#   'ATCGCCGCGC',
#   'TCGCCGCGCT',
#   'CGCCGCGCTC',
#   'CCGCGCTCGT',
#   'CGCGCTCGTC',
#   'GCGCTCGTCG',
#   'CGCTCGTCGT',
#   'GCTCGTCGTC',
#   'CTCGTCGTCG',
#   'TCGTCGTCGA',
#   'CGTCGTCGAC',
#   'CGTCGACAAC',
#   'GTCGACAACG',
#   'TCGACAACGG',
#   'CGACAACGGC',
#   'GACAACGGCT',
#   'CGGCTCCGGC',
#   'GGCTCCGGCA',
#   'GCTCCGGCAT',
#   'CTCCGGCATG',
#   'TCCGGCATGT',
#   'CGGCATGTGC',
#   'GGCATGTGCA',
#   'CATGTGCAAG',
#   'TGTGCAAGGC',
#   'GTGCAAGGCC',
#   'TGCAAGGCCG',
#   'GCAAGGCCGG',
#   'CAAGGCCGGC',
#   'AAGGCCGGCT',
#   'AGGCCGGCTT',
#   'GGCCGGCTTC',
#   'GCCGGCTTCG',
#   'CCGGCTTCGC',
#   'CGGCTTCGCG',
#   'GGCTTCGCGG',
#   'CTTCGCGGGC',
#   'TTCGCGGGCG',
#   'TCGCGGGCGA',
#   'CGCGGGCGAC',
#   'GCGGGCGACG',
#   'CGGGCGACGA',
#   'GGGCGACGAT',
#   'GGCGACGATG',
#   'GCGACGATGC',
#   'CGACGATGCC',
#   'GACGATGCCC',
#   'ACGATGCCCC',
#   'CGATGCCCCC',
#   'GATGCCCCCC',
#   'ATGCCCCCCG',
#   'TGCCCCCCGG',
#   'CCCCCCGGGC',
#   'CCCCCGGGCC',
#   'CCCCGGGCCG',
#   'CCCGGGCCGT',
#   'CCGGGCCGTC',
#   'CGGGCCGTCT',
#   'GGCCGTCTTC',
#   'CCGTCTTCCC',
#   'CGTCTTCCCC',
#   'GTCTTCCCCT',
#   'TCTTCCCCTC',
#   'CTTCCCCTCC',
#   'TCCCCTCCAT',
#   'CCCCTCCATC',
#   'CCCTCCATCG',
#   'CCTCCATCGT',
#   'CTCCATCGTG',
#   'TCCATCGTGG',
#   'CCATCGTGGG',
#   'TCGTGGGGCG',
#   'CGTGGGGCGC',
#   'GTGGGGCGCC',
#   'TGGGGCGCCC',
#   'GGGGCGCCCC',
#   'GGGCGCCCCA',
#   'GGCGCCCCAG',
#   'GCGCCCCAGG',
#   'CGCCCCAGGC',
#   'GCCCCAGGCA',
#   'CCCCAGGCAC',
#   'CCCAGGCACC',
#   'CCAGGCACCA',
#   'CAGGCACCAG',
#   'AGGCACCAGG',
#   'GCACCAGGGC',
#   'ACCAGGGCGT',
#   'CCAGGGCGTG',
#   'CAGGGCGTGA',
#   'AGGGCGTGAT',
#   'GGGCGTGATG',
#   'GGCGTGATGG',
#   'GCGTGATGGT',
#   'CGTGATGGTG',
#   'GTGATGGTGG',
#   'TGATGGTGGG',
#   'GGTGGGCATG',
#   'GTGGGCATGG',
#   'TGGGCATGGG',
#   'GGGCATGGGT',
#   'GGCATGGGTC',
#   'GCATGGGTCA',
#   'CATGGGTCAG',
#   'TGGGTCAGAA',
#   'GGTCAGAAGG',
#   'GTCAGAAGGA',
#   'TCAGAAGGAT',
#   'CAGAAGGATT',
#   'AGAAGGATTC',
#   'GAAGGATTCC',
#   'GGATTCCTAT',
#   'GATTCCTATG',
#   'TTCCTATGTG',
#   'TCCTATGTGG',
#   'CCTATGTGGG',
#   'CTATGTGGGC',
#   'TATGTGGGCG'],
#  159]

# %%
import datetime



def Testuj(instancje, typ): #typ czyli np "Instancje z błędami negatywnymi losowymi"
    wyniki=[]
    for instancja in instancje: # instancja = [nazwa pliku, N, L]
        rezultat = wykonaj(instancja) 
        #[czas,długość(uzyskana długość, długość sekwencji oryginalnej, liczba używych nukleotydów), sekwencja]                
        wynik = [instancja, rezultat]
        wyniki.append(wynik)
        
    return [typ, wyniki]
        
    
def wykonaj(instancja):# instancja = [nazwa pliku, N, L]
    L = instancja[2]
    N = instancja[1]
    S = read_data(instancja[0], L)    
   
    start = datetime.datetime.now()
    seq = sekwencjonuj(L, S, N, create_matrix(S))    
    czas = datetime.datetime.now() - start
    czas = czas.total_seconds()
    return [czas, [seq[0], N, seq[2]]]

# %%
#miejsce na testy
import math

names1=["9.200-40","9.200-80","18.200-40","18.200-80","35.200-40","35.200-80","20.300-60","20.300-120"
       ,"55.300-60","55.300-120","58.300-60","58.300-120","55.400-80","55.400-160","62.400-80","62.400-160"
      ,"68.400-80","68.400-160","10.500-100","10.500-200","25.500-100","25.500-200","53.500-100","53.500-200"]
names2=["59.500-2","113.500-8","144.500-12","28.500-18", "34.500-32"]
names3=["9.200+80","18.200+80","35.200+80", "20.300+120","55.300+120","58.300+120",
       "55.400+160","62.400+160","68.400+160","10.500+200","25.500+200","53.500+200"]
names4=["9.200+20","18.200+20","35.200+20", "20.300+30","55.300+30","58.300+30",
       "55.400+40","62.400+40","68.400+40","10.500+50","25.500+50","53.500+50"]

x=0

# czas, dł. sekwencji otrzymana, dł. sekwencji oczekiwana, ilość słów
#
for i in names1:
    print(Testuj([[i,200+100*math.floor(x/6)+9,10]], "Instancje z błędami negatywnymi losowymi"))
    x+=1
    
x=0
for i in names2:
    print(Testuj([[i,509,10]], "Instancje z błędami negatywnymi wynikającymi z powtórzeń"))

for i in names3:
    print(Testuj([[i,200+100*math.floor(x/3)+9,10]], "Instancje z błędami pozytywnymi losowymi"))
    x+=1
    
x=0
for i in names4:
    print(Testuj([[i,200+100*math.floor(x/3)+9,10]], "Instancje z błędami pozytywnymi, przekłamania na końcach oligonukleotydów"))
    x+=1
# Out:
# ['Instancje z błędami negatywnymi losowymi', [[['9.200-40', 209, 10], [0.450854, [206, 209, 159]]]]]
# ['Instancje z błędami negatywnymi losowymi', [[['9.200-80', 209, 10], [0.200932, [206, 209, 119]]]]]
# ['Instancje z błędami negatywnymi losowymi', [[['18.200-40', 209, 10], [0.444853, [209, 209, 155]]]]]
# ['Instancje z błędami negatywnymi losowymi', [[['18.200-80', 209, 10], [0.193937, [209, 209, 113]]]]]
# ['Instancje z błędami negatywnymi losowymi', [[['35.200-40', 209, 10], [0.450843, [207, 209, 157]]]]]
# ['Instancje z błędami negatywnymi losowymi', [[['35.200-80', 209, 10], [0.198933, [208, 209, 119]]]]]
# ['Instancje z błędami negatywnymi losowymi', [[['20.300-60', 309, 10], [1.474519, [309, 309, 235]]]]]
# ['Instancje z błędami negatywnymi losowymi', [[['20.300-120', 309, 10], [0.618789, [308, 309, 173]]]]]
# ['Instancje z błędami negatywnymi losowymi', [[['55.300-60', 309, 10], [1.468511, [309, 309, 233]]]]]
# ['Instancje z błędami negatywnymi losowymi', [[['55.300-120', 309, 10], [0.631794, [305, 309, 173]]]]]
# ['Instancje z błędami negatywnymi losowymi', [[['58.300-60', 309, 10], [1.40954, [304, 309, 230]]]]]
# ['Instancje z błędami negatywnymi losowymi', [[['58.300-120', 309, 10], [0.618794, [303, 309, 178]]]]]
# ['Instancje z błędami negatywnymi losowymi', [[['55.400-80', 409, 10], [3.330911, [409, 409, 308]]]]]
# ['Instancje z błędami negatywnymi losowymi', [[['55.400-160', 409, 10], [1.340559, [404, 409, 217]]]]]
# ['Instancje z błędami negatywnymi losowymi', [[['62.400-80', 409, 10], [3.385891, [409, 409, 309]]]]]
# ['Instancje z błędami negatywnymi losowymi', [[['62.400-160', 409, 10], [1.392544, [409, 409, 230]]]]]
# ['Instancje z błędami negatywnymi losowymi', [[['68.400-80', 409, 10], [3.357901, [409, 409, 309]]]]]
# ['Instancje z błędami negatywnymi losowymi', [[['68.400-160', 409, 10], [1.425533, [407, 409, 229]]]]]
# ['Instancje z błędami negatywnymi losowymi', [[['10.500-100', 509, 10], [6.581847, [509, 509, 394]]]]]
# ['Instancje z błędami negatywnymi losowymi', [[['10.500-200', 509, 10], [2.780089, [508, 509, 294]]]]]
# ['Instancje z błędami negatywnymi losowymi', [[['25.500-100', 509, 10], [6.551853, [509, 509, 392]]]]]
# ['Instancje z błędami negatywnymi losowymi', [[['25.500-200', 509, 10], [2.805082, [509, 509, 291]]]]]
# ['Instancje z błędami negatywnymi losowymi', [[['53.500-100', 509, 10], [6.616834, [504, 509, 391]]]]]
# ['Instancje z błędami negatywnymi losowymi', [[['53.500-200', 509, 10], [2.71511, [500, 509, 292]]]]]
# ['Instancje z błędami negatywnymi wynikającymi z powtórzeń', [[['59.500-2', 509, 10], [12.511902, [508, 509, 485]]]]]
# ['Instancje z błędami negatywnymi wynikającymi z powtórzeń', [[['113.500-8', 509, 10], [12.213003, [509, 509, 487]]]]]
# ['Instancje z błędami negatywnymi wynikającymi z powtórzeń', [[['144.500-12', 509, 10], [12.092043, [509, 509, 482]]]]]
# ['Instancje z błędami negatywnymi wynikającymi z powtórzeń', [[['28.500-18', 509, 10], [11.736161, [508, 509, 481]]]]]
# ['Instancje z błędami negatywnymi wynikającymi z powtórzeń', [[['34.500-32', 509, 10], [10.651513, [509, 509, 464]]]]]
# ['Instancje z błędami pozytywnymi losowymi', [[['9.200+80', 209, 10], [1.713439, [209, 209, 200]]]]]
# ['Instancje z błędami pozytywnymi losowymi', [[['18.200+80', 209, 10], [1.638463, [209, 209, 179]]]]]
# ['Instancje z błędami pozytywnymi losowymi', [[['35.200+80', 209, 10], [1.684448, [209, 209, 200]]]]]
# ['Instancje z błędami pozytywnymi losowymi', [[['20.300+120', 309, 10], [5.837091, [309, 309, 285]]]]]
# ['Instancje z błędami pozytywnymi losowymi', [[['55.300+120', 309, 10], [5.871078, [309, 309, 300]]]]]
# ['Instancje z błędami pozytywnymi losowymi', [[['58.300+120', 309, 10], [5.874076, [309, 309, 300]]]]]
# ['Instancje z błędami pozytywnymi losowymi', [[['55.400+160', 409, 10], [13.987421, [407, 409, 390]]]]]
# ['Instancje z błędami pozytywnymi losowymi', [[['62.400+160', 409, 10], [14.182354, [409, 409, 400]]]]]
# ['Instancje z błędami pozytywnymi losowymi', [[['68.400+160', 409, 10], [14.425277, [409, 409, 392]]]]]
# ['Instancje z błędami pozytywnymi losowymi', [[['10.500+200', 509, 10], [26.756239, [509, 509, 464]]]]]
# ['Instancje z błędami pozytywnymi losowymi', [[['25.500+200', 509, 10], [27.428021, [509, 509, 490]]]]]
# ['Instancje z błędami pozytywnymi losowymi', [[['53.500+200', 509, 10], [27.399029, [509, 509, 500]]]]]
# ['Instancje z błędami pozytywnymi, przekłamania na końcach oligonukleotydów', [[['9.200+20', 209, 10], [0.9167, [209, 209, 162]]]]]
# ['Instancje z błędami pozytywnymi, przekłamania na końcach oligonukleotydów', [[['18.200+20', 209, 10], [0.882713, [209, 209, 151]]]]]
# ['Instancje z błędami pozytywnymi, przekłamania na końcach oligonukleotydów', [[['35.200+20', 209, 10], [1.054653, [209, 209, 172]]]]]
# ['Instancje z błędami pozytywnymi, przekłamania na końcach oligonukleotydów', [[['20.300+30', 309, 10], [3.396887, [309, 309, 266]]]]]
# ['Instancje z błędami pozytywnymi, przekłamania na końcach oligonukleotydów', [[['55.300+30', 309, 10], [3.245938, [309, 309, 264]]]]]
# ['Instancje z błędami pozytywnymi, przekłamania na końcach oligonukleotydów', [[['58.300+30', 309, 10], [3.146968, [309, 309, 243]]]]]
