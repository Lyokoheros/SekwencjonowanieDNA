# %%
def initbool(dlugosc):
    return [False for i in range(dlugosc)]

def create_matrix(words):
    L = len(words[0])
    matrix = []
    for i in range(len(words)):
        row = []
        for j in range(len(words)):
            suc = 0
            if i==j:
                row.append(1000)
                continue
            for x in range(1,L):
                if words[i][x:] == words[j][:L-x]:
                    row.append(x)
                    suc = 1
                    break
            if suc==0: 
                row.append(L)
        matrix.append(row)


    return(matrix)


def sekwencjonuj(L, S, N, Graf): 
#L - długość słowa, S - zbiór słów,
#N - długość oryginalnej sekwencji, Graf - utworzony graf z wagami (x->y)
#zbiór S uporządkowany tak samo jak graf!

    def DFS(DlugoscSekwencji, Sekwencja, wyrazy, indeks, najlepsze):
        
        odwiedzone[indeks] = True
        for i in range(len(S)):
            if odwiedzone[i] == False:
                if DlugoscSekwencji+Graf[i][indeks] < N:
                    DFS(DlugoscSekwencji+Graf[i][indeks], Sekwencja.append(S[indeks]), wyrazy+1, i, najlepsze)
                elif DlugoscSekwencji+Graf[i][indeks] == N:
                    if wyrazy+1 > najlepsze[2]:  # rozwiązanie[...,wyrazy,...]
                        najlepsze[2] = wyrazy + 1 #wyrazy
                        najlepsze[1] = Sekwencja.append(S[i])#sekwencja
                        najlepsze[0] = DlugoscSekwencji+graf[i][indeks]#długość sekwencji
                else: # DlugoscSekwnecji+Graf[i][indeks] > N
                    if wyrazy > najlepsze[2]:  # rozwiązanie[...,wyrazy,...]
                        najlepsze[2] = wyrazy #wyrazy
                        najlepsze[1] = Sekwencja #sekwencja
                        najlepsze[0] = DlugoscSekwencji #długość sekwencji
        return najlepsze
                    
    DlugoscSekwencji = L
    wyrazy = 1
    Sekwencja = [S[0]]

    rozwiazanie=[DlugoscSekwencji, Sekwencja, wyrazy]
    #długość sekwencji w najlepszym (logalnie) rozwiązaniu
    #sekwencja w najlepszym rozwiązaniu
    #ilość wyrazów w najlepszym rozwiązaniu

        
    for i in range(len(S)):
        odwiedzone=initbool(len(S))
        noweRozwiazanie=DFS(L,  [S[i]], 1, i, rozwiazanie)
        
        if noweRozwiazanie[2] > rozwiazanie[2]:
            rozwiazanie = noweRozwiazanie 
            #preferowane jestrozwiązanie o większej lizbie wyrazów...
        elif noweRozwiazanie[2] == rozwiazanie[2] and noweRozwiazanie[0] < rozwiazanie[0]:
            #...a spośród tych mających tyle samo wyrazów to, które ma mniejszą długość
            rozwiazanie = noweRozwiazanie 
    

    return rozwiazanie
    
#dane testowe
    
S=["AAT", "ACG", "CCG", "CGT", "GAC", "TTG"]

graf= [[1000, 3, 3, 3, 3, 2],
       [3, 1000, 3, 1, 2, 3],
       [3, 3, 1000, 1, 2, 3],
       [3, 3, 3, 1000, 3, 2], 
       [3, 1, 2, 2, 1000, 3], 
       [3, 3, 3, 3, 2, 1000]]

L = 3
N = 8
seq = sekwencjonuj(L, S, N, create_matrix(S))
seq[1]

#DFS(DlugoscSekwencji, Sekwescja, wyrazy, indeks, najlepsze)
#DFS(DlugoscSekwencji+Graf[i][indeks], Sekwencja.append(S[indeks]), wyrazy+1, i, najlepsze)
#DFS(L,  [S[i]], wyrazy, i, rozwiazanie)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-5c7801f7d4e2> in <module>
#      86 L = 3
#      87 N = 8
# ---> 88 seq = sekwencjonuj(L, S, N, create_matrix(S))
#      89 seq[1]
#      90
#
# <ipython-input-26-5c7801f7d4e2> in sekwencjonuj(L, S, N, Graf)
#      61     for i in range(len(S)):
#      62         odwiedzone=initbool(len(S))
# ---> 63         noweRozwiazanie=DFS(L,  [S[i]], 1, i, rozwiazanie)
#      64
#      65         if noweRozwiazanie[2] > rozwiazanie[2]:
#
# <ipython-input-26-5c7801f7d4e2> in DFS(DlugoscSekwencji, Sekwencja, wyrazy, indeks, najlepsze)
#      36             if odwiedzone[i] == False:
#      37                 if DlugoscSekwencji+Graf[i][indeks] < N:
# ---> 38                     DFS(DlugoscSekwencji+Graf[i][indeks], Sekwencja.append(S[indeks]), wyrazy+1, i, najlepsze)
#      39                 elif DlugoscSekwencji+Graf[i][indeks] == N:
#      40                     if wyrazy+1 > najlepsze[2]:  # rozwiązanie[...,wyrazy,...]
#
# <ipython-input-26-5c7801f7d4e2> in DFS(DlugoscSekwencji, Sekwencja, wyrazy, indeks, najlepsze)
#      36             if odwiedzone[i] == False:
#      37                 if DlugoscSekwencji+Graf[i][indeks] < N:
# ---> 38                     DFS(DlugoscSekwencji+Graf[i][indeks], Sekwencja.append(S[indeks]), wyrazy+1, i, najlepsze)
#      39                 elif DlugoscSekwencji+Graf[i][indeks] == N:
#      40                     if wyrazy+1 > najlepsze[2]:  # rozwiązanie[...,wyrazy,...]
#
# AttributeError: 'NoneType' object has no attribute 'append'

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-f7cfdb55bdda> in <module>
#      10 L = 3
#      11 N = 8
# ---> 12 seq = sekwencjonuj(L, S, N, graf)
#      13 seq[1]
#      14
#
# <ipython-input-22-e5d6f162b4e1> in sekwencjonuj(L, S, N, Graf)
#      40     for i in range(len(S)):
#      41         odwiedzone=initbool(len(S))
# ---> 42         noweRozwiazanie=DFS(L,  [S[i]], 1, i, rozwiazanie)
#      43
#      44         if noweRozwiazanie[2] > rozwiazanie[2]:
#
# <ipython-input-22-e5d6f162b4e1> in DFS(DlugoscSekwencji, Sekwencja, wyrazy, indeks, najlepsze)
#      24             if odwiedzone[i] == False:
#      25                 if DlugoscSekwencji+Graf[i][indeks] < N:
# ---> 26                     DFS(DlugoscSekwencji+Graf[i][indeks], Sekwencja.append(S[indeks]), wyrazy+1, i, najlepsze)
#      27                 elif DlugoscSekwencji+Graf[i][indeks] == N:
#      28                     if wyrazy+1 > najlepsze[2]:  # rozwiązanie[...,wyrazy,...]
#
# <ipython-input-22-e5d6f162b4e1> in DFS(DlugoscSekwencji, Sekwencja, wyrazy, indeks, najlepsze)
#      24             if odwiedzone[i] == False:
#      25                 if DlugoscSekwencji+Graf[i][indeks] < N:
# ---> 26                     DFS(DlugoscSekwencji+Graf[i][indeks], Sekwencja.append(S[indeks]), wyrazy+1, i, najlepsze)
#      27                 elif DlugoscSekwencji+Graf[i][indeks] == N:
#      28                     if wyrazy+1 > najlepsze[2]:  # rozwiązanie[...,wyrazy,...]
#
# AttributeError: 'NoneType' object has no attribute 'append'
